# %%
import os
import pandas as pd
from bs4 import BeautifulSoup as bs
import requests
from splinter import Browser
# from twitterscraper import query_tweets
import datetime as dt
# browser = Browser('firefox')
headers = requests.utils.default_headers()
# articles = requests.utils.default_lists()
import random

# %%
# !which chromedriver
# Out:
# /usr/local/bin/chromedriver

# %%
executable_path = {'executable_path': '/usr/local/bin/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
mars_url = 'https://mars.nasa.gov/news/'
req = requests.get(mars_url, 'li')
soup = bs(req.content, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <!-- Always force latest IE rendering engine or request Chrome Frame -->
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"5e33925808","applicationID":"59562082","transactionName":"JVcPR0MLWApSRU1eAQVVEhxSC1oSUlkWbBMHXwRAHhdcCUA=","queueTime":0,"applicationTime":351,"agent":""}
#   </script>
#   <script type="text/javascript">
# ...

# %%
article_titles = soup.find_all(class_="content_title")
# soup_title = bs(req.title, 'lxml')

article_titles
# Out:
# [<div class="content_title">
#  <a href="/news/8659/alabama-high-school-student-names-nasas-mars-helicopter/">
#  Alabama High School Student Names NASA's Mars Helicopter
#  </a>
#  </div>,
#  <div class="content_title">
#  <a href="/news/8645/mars-helicopter-attached-to-nasas-perseverance-rover/">
#  Mars Helicopter Attached to NASA's Perseverance Rover
#  </a>
#  </div>,
#  <div class="content_title">
#  <a href="/news/8641/nasas-perseverance-mars-rover-gets-its-wheels-and-air-brakes/">
#  NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes
#  </a>
#  </div>,
#  <div class="content_title">
#  <a href="/news/8634/109-million-names-now-aboard-nasas-perseverance-mars-rover/">
#  10.9 Million Names Now Aboard NASA's Perseverance Mars Rover
#  </a>
#  </div>,
#  <div class="content_title">
#  <a href="/news/8622/virginia-middle-school-student-earns-honor-of-naming-nasas-next-mars-rover/">
#  Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover
#  </a>
# ...

# %%
for titles in article_titles:
    a = titles.find('a')
    href = titles.find('href')
    title_text = titles.text
    print(title_text)
# Out:
# Alabama High School Student Names NASA's Mars Helicopter
#
#
#
#
# Mars Helicopter Attached to NASA's Perseverance Rover
#
#
#
#
# NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes
#
#
#
#
# 10.9 Million Names Now Aboard NASA's Perseverance Mars Rover
#
#
#
#
# Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover
#
#
#
#
# NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network

# %%
article_description = soup.find_all(class_="rollover_description_inner")
article_description

for summary in article_description:
    a = summary.find('a')
    div = summary.find('div')
    href = summary.find('href')
    summary_text = summary.text
    print(summary_text)
# Out:
# Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.
#
#
# The team also fueled the rover's sky crane to get ready for this summer's history-making launch.
#
#
# After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.
#
#
# As part of NASA's 'Send Your Name to Mars' campaign, they've been stenciled onto three microchips along with essays from NASA's 'Name the Rover' contest. Next stop: Mars.
#
#
# NASA chose a seventh-grader from Virginia as winner of the agency's "Name the Rover" essay contest. Alexander Mather's entry for "Perseverance" was voted tops among 28,000 entries.
#
#
# Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.

# %%
# news_list = soup.find_all(class_="image_and_description_container")

# for list_summary in news_list:
#     a = list_summary.find('a')
#     div = list_summary.find('div')
#     href = list_summary.find('href')
#     title = list_summary.find("bottom_gradient", 'h3')
#     text = list_summary.text
#     print(title)
#     print(text)
# # news_list

results = soup.find_all('div', class_="slide")
for result in results:
    titles = result.find('div', class_="content_title")
    title = titles.find('a').text
    bodies = result.find('div', class_="rollover_description")
    body = bodies.find('div', class_="rollover_description_inner").text
    print('----------------')
    print(title)
    print(body)
# Out:
# ----------------
#
# Alabama High School Student Names NASA's Mars Helicopter
#
#
# Vaneeza Rupani's essay was chosen as the name for the small spacecraft, which will mark NASA's first attempt at powered flight on another planet.
#
# ----------------
#
# Mars Helicopter Attached to NASA's Perseverance Rover
#
#
# The team also fueled the rover's sky crane to get ready for this summer's history-making launch.
#
# ----------------
#
# NASA's Perseverance Mars Rover Gets Its Wheels and Air Brakes
#
#
# After the rover was shipped from JPL to Kennedy Space Center, the team is getting closer to finalizing the spacecraft for launch later this summer.
#
# ----------------
#
# 10.9 Million Names Now Aboard NASA's Perseverance Mars Rover
#
#
# As part of NASA's 'Send Your Name to Mars' campaign, they've been stenciled onto three microchips along with essays from NASA's 'Name the Rover' contest. Next stop: Mars.
#
# ----------------
#
# ...

# %%
# article_titles = soup.find_all(class_="content_title")
# article_description = soup.find_all(class_="rollover_description_inner")
# news_date = soup.find_all("list_date")
# news_list = soup.find_all(class_="image_and_description_container")

# article_date = []
# article_title = []
# article_desc = []

# for list_summary in news_list:
#     article_titles = soup.find_all(class_="content_title")
#     article_description = soup.find_all(class_="rollover_description_inner")
#     article_date = soup.find_all(class_="list_date")
#     for titles in article_titles:
#         a = titles.find('a')
#         href = titles.find('href')
#         title_text = titles.text
#         article_title.append(title_text)
#     for summary in article_description:
#         a = summary.find('a')
#         div = summary.find('div')
#         href = summary.find('href')
#         summary_text = summary.text
#         article_desc.append(summary_text)      
#     for date in news_date:
#         obj_date = date.find(class_="list_date")
#         article_date.append(obj_date)
# pd.DataFrame(headers=["article_date", "article_title", "article_desc"])

# # for list_summary in news_list:
# #     a = list_summary.find('a')
# #     list_text = a.find(class_="rollover_description_inner")
# #     date = a.find(class_="list_date")
# #     list_title = a.find(class_="content_title")
# # #     title_text = list_title.text
# #     print(list_text)
# #     print(date)
# #     print(list_title)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-100-7317f2d91b5c> in <module>
#      26         obj_date = date.find(class_="list_date")
#      27         article_date.append(obj_date)
# ---> 28 pd.DataFrame(headers=["article_date", "article_title", "article_desc"])
#      29
#      30 # for list_summary in news_list:
#
# TypeError: __init__() got an unexpected keyword argument 'headers'

# %%
images_url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(images_url)

# %%
image_list = []

for x in range(1, 6):
    html = browser.html
    image_soup = bs(html, 'html.parser')
    
    images = image_soup.find_all('img', class_="thumb")
    
    for image in images:
        image_list.append(image.get('src'))
#         print(image.get('src'))
        
    browser.links.find_by_partial_text('Next')
    

final_image = random.choice(image_list)
final_image
# Out:
# '/spaceimages/images/wallpaper/PIA23901-640x350.jpg'

# %%
# twitter_url = 'https://twitter.com/marswxreport?lang=en'
# twitter_req = requests.get(twitter_url)
# twitter_soup = bs(twitter_req.content, 'lxml')

# print(twitter_soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=0,viewport-fit=cover" name="viewport"/>
#   <link href="//abs.twimg.com" rel="preconnect"/>
#   <link href="//api.twitter.com" rel="preconnect"/>
#   <link href="//pbs.twimg.com" rel="preconnect"/>
#   <link href="//t.co" rel="preconnect"/>
#   <link href="//video.twimg.com" rel="preconnect"/>
#   <link href="//abs.twimg.com" rel="dns-prefetch"/>
#   <link href="//api.twitter.com" rel="dns-prefetch"/>
#   <link href="//pbs.twimg.com" rel="dns-prefetch"/>
#   <link href="//t.co" rel="dns-prefetch"/>
#   <link href="//video.twimg.com" rel="dns-prefetch"/>
#   <link as="script" crossorigin="anonymous" href="https://abs.twimg.com/responsive-web/web/polyfills.604422d4.js" nonce="OWU3ODllNWUtZGRkMi00Y2RjLTljMzAtNTZjYzcwYTljNDBl" rel="preload"/>
# ...

# %%
# tweet = twitter_soup.find_all(role_="article")
# tweet
# Out:
# []

# %%
# Mars Facts

facts_url = 'https://space-facts.com/mars/'
data = pd.read_html(facts_url)
data_df = data[0]

data_df.to_html('data_html.html')
# df.to_html('filename.html')
# data_html.save

# %%
# Mars Hemispheres
hemisphere = ['Cerebrus', 'Schiaparelli', 'Syrtis_major', 'Valles_Marineris']
img_url = []
title = []

hemispher_image_urls = []


images_url = 'https://www.jpl.nasa.gov/spaceimages/?search=&category=Mars'
browser.visit(images_url)




URL_PATTERN = 'https://astrogeology.usgs.gov/search/map/Mars/Viking/{}_enhanced'
for hemisphere in hemisphere:
    hemi_url = URL_PATTERN.format(hemisphere)
    
    for url in url:
        hemi_soup = requests.get(hemi_url)
        
        for url in hemi_url:
            hemi_img = hemi_soup.find_all('dd')
            img_url.append(hemi_img.get('href'))
    
# hemi_response = requests.get(hemi_url)
# print(hemi_response.prettify())

image_list = []

for x in range(1, 6):
    html = browser.html
    image_soup = bs(html, 'html.parser')
    
    images = image_soup.find_all('dd', class_="tooltip word-tif")
    
    for image in images:
        image_list.append(image.get('src'))
#         print(image.get('src'))
        
#     browser.links.find_by_partial_text('Next')
    

# final_image = random.choice(image_list)
# final_image
# Out:
# https://astrogeology.usgs.gov/search/map/Mars/Viking/Cerebrus_enhanced
# https://astrogeology.usgs.gov/search/map/Mars/Viking/Schiaparelli_enhanced
# https://astrogeology.usgs.gov/search/map/Mars/Viking/Syrtis_major_enhanced
# https://astrogeology.usgs.gov/search/map/Mars/Viking/Valles_Marineris_enhanced

# %%
hemisphere_image_urls = [
    {"title": "Valles Marineris Hemisphere", "img_url": "..."},
    {"title": "Cerberus Hemisphere", "img_url": "..."},
    {"title": "Schiaparelli Hemisphere", "img_url": "..."},
    {"title": "Syrtis Major Hemisphere", "img_url": "..."},
]
